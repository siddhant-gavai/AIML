# %%
conda install panda
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: -
# \
# |
# /
# -
# done
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# /
# -
# \
# |
# done
# Solving environment: -
# \
# |
# failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - panda
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
s = pd.Series([90, 80, 93 , 84 , 78] , index=["marathi" , "Hindi" , "english" , "math" , "History"])
print(s)
# Out:
# marathi    90
# Hindi      80
# english    93
# math       84
# History    78
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s["marathi"]
# Out:
# np.int64(90)

# %%
data = {
    "Name" : ["siddhant" , "onkar" , "yash"],
    "Age" : ["21" , "21", "21"],
    "City" : ["Hingoli" , "AhilyaNagar" , "Chalisgoan"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        Name Age         City
# 0  siddhant  21      Hingoli
# 1     onkar  21  AhilyaNagar
# 2      yash  21   Chalisgoan

# %%
df.index #Row labeles
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns #Column labels
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')
