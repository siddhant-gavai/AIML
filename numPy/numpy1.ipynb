# %%
import numpy as np
import time

# %%
#execution perfomance
size = 1_000_000

#python list 
py_list =  list(range(size))
start = time.time()
sq_list = [x**2 for x in py_list]

np_array =  np.array(py_list)
